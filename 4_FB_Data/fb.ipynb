# %%
import pandas as pd

# %%
df = pd.read_csv('./fb.csv')

# %%
sub = df[['Type' , 'Category' , 'like' ]]

# %%
sub
# Out:
#        Type  Category    like
# 0     Photo         2    79.0
# 1    Status         2   130.0
# 2     Photo         3    66.0
# 3     Photo         2  1572.0
# 4     Photo         2   325.0
# ..      ...       ...     ...
# 495   Photo         3    53.0
# 496   Photo         2    53.0
# 497   Photo         1    93.0
# 498   Photo         3    91.0
# 499   Photo         2    91.0
#
# [500 rows x 3 columns]

# %%
sub_filter = sub[sub['like'] > 100]

# %%
sub_filter
# Out:
#        Type  Category    like
# 1    Status         2   130.0
# 3     Photo         2  1572.0
# 4     Photo         2   325.0
# 5    Status         2   152.0
# 6     Photo         3   249.0
# ..      ...       ...     ...
# 488   Photo         3   277.0
# 491   Photo         3   105.0
# 492    Link         1   128.0
# 493   Photo         3   185.0
# 494   Photo         3   125.0
#
# [252 rows x 3 columns]

# %%
sub_filter.to_html('OKOK.html')

# %% [markdown]
# # 2. Merging Data

# %%
df1 = df[df['like'] > 200] 
df2 = df[df['Category'] == 3]

# %%
df1.merge(df2 , how='outer').shape
df1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 3              139441   Photo         2          12             2         10  \
# 4              139441   Photo         2          12             2          3
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 10             139441  Status         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 464             92079   Photo         1           2             6         13
# 468             91651   Photo         1           2             4         12
# 476             86909   Photo         1           1             6         10
# 480             86909   Photo         2           1             4         11
# 488             85979   Photo         3           1             7         10
#
# ...

# %% [markdown]
# # 3. Sort Data

# %%
sorted_data = df.sort_values(by='like' , ascending=False)

# %% [markdown]
# # 4. Transpose

# %%
df_transposed = df.T

# %% [markdown]
# # 5. Melting

# %%
df_transposed
# Out:
#                                                        0       1       2
# Page total likes                                    139441  139441  139441  \
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df_transposed.melt()
# Out:
#       variable   value
# 0            0  139441
# 1            0   Photo
# 2            0       2
# 3            0      12
# 4            0       4
# ...        ...     ...
# 9495       499     316
# 9496       499       0
# 9497       499    91.0
# 9498       499    28.0
# 9499       499     119
#
# [9500 rows x 2 columns]

# %% [markdown]
# # 6. Casting

# %%
df_likeOnly = df['like'].astype('bool')
dir(df_likeOnly)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %% [markdown]
# # Assignment 7

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(x=df['Type'] , height=df['like'])
# Out:
# <BarContainer object of 500 artists>

# %%
plt.scatter(x = df['Lifetime People who have liked your Page and engaged with your post'] , y = df['like'])

# %%
plt.plot(df['Post Month'] , df['Page total likes'])

# %%
sub_filter.plot.area()
# Out:
# <Axes: >

# %% [markdown]
# # Seaborn

# %%
import seaborn as sb

# %%
sb.scatterplot(x = df['like'] , y = df['Type'], hue=df['Category'])
# Out:
# <Axes: xlabel='like', ylabel='Type'>

# %%
sb.boxenplot(data=df['like'])
# Out:
# <Axes: >

# %%
sb.lineplot(x='like' , y='comment' , data=df)
# Out:
# <Axes: xlabel='like', ylabel='comment'>
